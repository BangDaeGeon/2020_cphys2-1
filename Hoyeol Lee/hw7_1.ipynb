# %% [markdown]
# # 2016017032 물리학과 이호열

# %% [markdown]
# # MNIST
# ## MNIST 손글씨 이미지를 다음의 방법으로 분류하고 test data를 이용하여 정확도를 비교하여라.
# 1. Softmax Regression
# 2. Support Vector Machine
# 3. Decision tree or Random forest

# %%
from keras.datasets import mnist
from tensorflow import keras
from keras import models 
from keras import layers
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical

(X, y), (Xtest, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ### 1. Softmax Regression

# %%
y_train=to_categorical(y)
y_test=to_categorical(y_test)

net = models.Sequential()
net.add(layers.Dense(10, activation='softmax', input_shape=(28*28,)))

# %%
net.compile(optimizer='sgd',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
X_train = X.reshape((60000, 28*28))
X_train = X_train/255

X_test = Xtest.reshape((10000, 28*28))
X_test = X_test/255

# %%
net.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.7830 - accuracy: 0.8111
# Epoch 2/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4587 - accuracy: 0.8803
# Epoch 3/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4051 - accuracy: 0.8904
# Epoch 4/20
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.3782 - accuracy: 0.8968
# Epoch 5/20
# 1875/1875 [==============================] - 2s 939us/step - loss: 0.3611 - accuracy: 0.9013
# Epoch 6/20
# 1875/1875 [==============================] - 2s 924us/step - loss: 0.3492 - accuracy: 0.9037
# Epoch 7/20
# 1875/1875 [==============================] - 2s 898us/step - loss: 0.3400 - accuracy: 0.9060
# Epoch 8/20
# 1875/1875 [==============================] - 2s 931us/step - loss: 0.3327 - accuracy: 0.9076
# Epoch 9/20
# 1875/1875 [==============================] - 2s 912us/step - loss: 0.3268 - accuracy: 0.9089
# Epoch 10/20
# 1875/1875 [==============================] - 2s 911us/step - loss: 0.3219 - accuracy: 0.9101
# Epoch 11/20
# 1875/1875 [==============================] - 2s 900us/step - loss: 0.3175 - accuracy: 0.9118
# Epoch 12/20
# 1875/1875 [==============================] - 2s 919us/step - loss: 0.3138 - accuracy: 0.9129
# Epoch 13/20
# 1875/1875 [==============================] - 2s 930us/step - loss: 0.3106 - accuracy: 0.9136
# Epoch 14/20
# 1875/1875 [==============================] - 2s 924us/step - loss: 0.3077 - accuracy: 0.9144
# Epoch 15/20
# 1875/1875 [==============================] - 2s 940us/step - loss: 0.3052 - accuracy: 0.9154
# Epoch 16/20
# 1875/1875 [==============================] - 2s 947us/step - loss: 0.3028 - accuracy: 0.9155
# Epoch 17/20
# 1875/1875 [==============================] - 2s 941us/step - loss: 0.3007 - accuracy: 0.9165
# Epoch 18/20
# 1875/1875 [==============================] - 2s 944us/step - loss: 0.2987 - accuracy: 0.9170
# Epoch 19/20
# 1875/1875 [==============================] - 2s 945us/step - loss: 0.2968 - accuracy: 0.9173
# Epoch 20/20
# 1875/1875 [==============================] - 2s 990us/step - loss: 0.2951 - accuracy: 0.9178

# %%
net.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 0s 786us/step - loss: 0.2878 - accuracy: 0.9194
# [0.2877860963344574, 0.9193999767303467]

# %%
test_loss, test_acc = net.evaluate(X_test, y_test)
print('테스트 정확도:', test_acc)
# Out:
# 313/313 [==============================] - 0s 771us/step - loss: 0.2878 - accuracy: 0.9194
# 테스트 정확도: 0.9193999767303467
